# %%
import pandas as pd

files = [
    "2019-Oct.csv",
    "2019-Nov.csv",
    "2019-Dec.csv",
    "2020-Jan.csv",
    "2020-Feb.csv"
]

for file in files:
    df = pd.read_csv(file, nrows=5)
    print(file)
    print(df.columns.tolist())
    print("-" * 50)
# Out:
# 2019-Oct.csv
# ['event_time', 'event_type', 'product_id', 'category_id', 'category_code', 'brand', 'price', 'user_id', 'user_session']
# --------------------------------------------------
# 2019-Nov.csv
# ['event_time', 'event_type', 'product_id', 'category_id', 'category_code', 'brand', 'price', 'user_id', 'user_session']
# --------------------------------------------------
# 2019-Dec.csv
# ['event_time', 'event_type', 'product_id', 'category_id', 'category_code', 'brand', 'price', 'user_id', 'user_session']
# --------------------------------------------------
# 2020-Jan.csv
# ['event_time', 'event_type', 'product_id', 'category_id', 'category_code', 'brand', 'price', 'user_id', 'user_session']
# --------------------------------------------------
# 2020-Feb.csv
# ['event_time', 'event_type', 'product_id', 'category_id', 'category_code', 'brand', 'price', 'user_id', 'user_session']
# --------------------------------------------------

# %%
import pandas as pd

sample = pd.read_csv("2019-Oct.csv", nrows=100000)

print(sample["event_type"].value_counts())
# Out:
# event_type
# view                43657
# cart                29587
# remove_from_cart    19912
# purchase             6844
# Name: count, dtype: int64

# %%
for file in files:
    df = pd.read_csv(file)
    print(file, df.shape)
# Out:
# 2019-Oct.csv (4102283, 9)
# 2019-Nov.csv (4635837, 9)
# 2019-Dec.csv (3533286, 9)
# 2020-Jan.csv (4264752, 9)
# 2020-Feb.csv (4156682, 9)
